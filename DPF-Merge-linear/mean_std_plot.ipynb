# %%
path1 = "logs/5_NF^True_DPF_0.25_0.001_resample^soft_CRNVP_maze_nav01_0.1_1e-05_elbo_0.01_split_0.9_mode_offline_slice_size_10_onlinetype_elbo/data/"
path2 = "logs/5_NF^True_DPF_0.25_0.001_resample^soft_CRNVP_maze_nav01_0.1_1e-05_elbo_0.01_split_0.9_mode_offline_slice_size_10_onlinetype_fix/data/"
path3 = "logs/5_NF^True_DPF_0.25_0.001_resample^soft_CRNVP_maze_nav01_0.1_1e-05_elbo_0.01_split_0.9_mode_offline_slice_size_10_onlinetype_rmse/data/"
# savepath = "result/meanstd_1_rmse.png"
savepath = "result/meanstd_1_elbo.png"

# %%
path1 = "logs/5_NF^True_DPF_0.25_0.001_resample^soft_CRNVP_maze_nav01_0.1_1e-05_elbo_0.01_split_0.9_mode_offline_slice_size_100_onlinetype_elbo/data/"
path2 = "logs/5_NF^True_DPF_0.25_0.001_resample^soft_CRNVP_maze_nav01_0.1_1e-05_elbo_0.01_split_0.9_mode_offline_slice_size_100_onlinetype_fix/data/"
path3 = "logs/5_NF^True_DPF_0.25_0.001_resample^soft_CRNVP_maze_nav01_0.1_1e-05_elbo_0.01_split_0.9_mode_offline_slice_size_100_onlinetype_rmse/data/"
savepath = "result/meanstd_2_rmse.png"
# savepath = "result/meanstd_2.png"

# %%
path1 = "test/sto_test_autoencoder_plots_aesmc_0.02_5_500_1_DPF_1.0"
# path2 = "test/test_autoencoder_plots_aesmc_0.02_1_500_1_SDPF_pl_1.0"
path3 = "test/sto_test_autoencoder_plots_aesmc_0.02_5_500_1_SDPF_elbo_1.0"
savepath = "result/rmse_param11.png"

# %%
path1 = "test/test_autoencoder_plots_aesmc_0.02_1_500_1_DPF_0.1"
path2 = "test/test_autoencoder_plots_aesmc_0.02_1_500_1_SDPF_elbo_0.1"
path3 = "test/test_autoencoder_plots_aesmc_0.02_1_500_1_SDPF_pl_0.1"
savepath = "result/meanstd_param2.png"

# %%
path1 = "DPF-Merge/logs_traj1001/5_NF^False_DPF_0.25_0.001_resample^soft_cos_maze_nav02_0.1_1e-05_elbo_0.001_mix_split_0.1/data"
# path2 = "DPF-Merge/logs_traj100/de_elbo_5_NF^False_DPF_0.25_0.001_resample^soft_cos_maze_nav01_0.1_1e-05_elbo_0.001_mix_split_0.1/data"
path2 = "DPF-Merge/logs_traj1001/5_NF^False_SDPF_0.25_0.001_resample^soft_cos_maze_nav02_0.1_0.0001_elbo_0.001_mix_split_0.1/data"
path3 = "DPF-Merge/logs_traj1001/lstm_5_NF^False_DPF_0.25_0.05_resample^soft_cos_maze_nav02_0.1_0.01/data"
savepath = "result/meanstd_maze2.png"

# %%
path1 = "DPF-Merge/logs_traj1001/5_NF^False_DPF_0.25_0.001_resample^soft_cos_maze_nav03_0.1_1e-05_elbo_0.001_mix_split_0.1/data"
# path2 = "DPF-Merge/logs_traj100/de_elbo_5_NF^False_DPF_0.25_0.001_resample^soft_cos_maze_nav01_0.1_1e-05_elbo_0.001_mix_split_0.1/data"
path2 = "DPF-Merge/logs_traj1001/5_NF^False_SDPF_0.25_0.001_resample^soft_cos_maze_nav03_0.1_0.0001_elbo_0.001_mix_split_0.1/data"
path3 = "DPF-Merge/logs_traj1001/lstm_5_NF^False_DPF_0.25_0.05_resample^soft_cos_maze_nav03_0.1_0.01/data"
savepath = "result/meanstd_maze3.png"

# %%
import numpy as np
import os

mean1=np.load(os.path.join(path1, 'online_rmse.npy'))
mean2=np.load(os.path.join(path2, 'online_rmse.npy'))
mean3=np.load(os.path.join(path3, 'online_rmse.npy'))
std1=np.load(os.path.join(path1, 'online_rmse.npy'))
std2=np.load(os.path.join(path2, 'online_rmse.npy'))
std3=np.load(os.path.join(path3, 'online_rmse.npy'))
print(mean1.shape)
print(mean3.shape)
# Out:
# (9000,)
# (9000,)

# %%
import numpy as np
import os

mean1=np.load(os.path.join(path1, 'online_elbo.npy'))
mean2=np.load(os.path.join(path2, 'online_elbo.npy'))
mean3=np.load(os.path.join(path3, 'online_elbo.npy'))
std1=np.load(os.path.join(path1, 'online_rmse.npy'))
std2=np.load(os.path.join(path2, 'online_rmse.npy'))
std3=np.load(os.path.join(path3, 'online_rmse.npy'))
print(mean1.shape)
print(mean3.shape)
# Out:
# (9000,)
# (9000,)

# %%
import numpy as np
import os

mean1=np.load(os.path.join(path1, 'online_eval_elbo.npy')).mean()
mean2=np.load(os.path.join(path2, 'online_eval_elbo.npy')).mean()
mean3=np.load(os.path.join(path3, 'online_eval_elbo.npy')).mean()
std1=np.load(os.path.join(path1, 'online_eval_elbo.npy')).std()
std2=np.load(os.path.join(path2, 'online_eval_elbo.npy')).std()
std3=np.load(os.path.join(path3, 'online_eval_elbo.npy')).std()
print(mean1,std1)
print(mean2,std2)
print(mean3,std3)
# Out:
# 10.190624 2.1239674
# -12.925072 3.5582066
# -366.5578 82.94499

# %%
import numpy as np
import os

mean1=np.load(os.path.join(path1, 'online_eval_loss.npy')).mean()
mean2=np.load(os.path.join(path2, 'online_eval_loss.npy')).mean()
mean3=np.load(os.path.join(path3, 'online_eval_loss.npy')).mean()
std1=np.load(os.path.join(path1, 'online_eval_loss.npy')).std()
std2=np.load(os.path.join(path2, 'online_eval_loss.npy')).std()
std3=np.load(os.path.join(path3, 'online_eval_loss.npy')).std()
print(mean1,std1)
print(mean2,std2)
print(mean3,std3)
# Out:
# 577.5679 211.49988
# 601.1921 218.5775
# 485.3617 133.7529

# %%
import numpy as np
import os

mean1=np.load(os.path.join(path1, 'aesmc_elbo_recorder_0.02_5_500_1.npy'))[:,52:102].mean(0)
std1=np.load(os.path.join(path1, 'aesmc_elbo_recorder_0.02_5_500_1.npy'))[:,52:102].std(0)
# mean2=np.load(os.path.join(path2, 'aesmc_parameter_error_recorder_0.02_1_500_1.npy'))[0][51:71]
# std2=np.load(os.path.join(path1, 'aesmc_parameter_error_recorder_0.02_1_500_1.npy'))[0][51:71]
mean3=np.load(os.path.join(path3, 'aesmc_elbo_recorder_0.02_5_500_1.npy'))[:,52:102].mean(0)
std3=np.load(os.path.join(path3, 'aesmc_elbo_recorder_0.02_5_500_1.npy'))[:,52:102].std(0)
print(mean1.shape, mean3.shape)
# Out:
# (50,) (50,)

# %%
import numpy as np
import os

mean1=np.load(os.path.join(path1, 'aesmc_loss_rmse_test_0.02_1_500_1.npy'))
std1=np.load(os.path.join(path1, 'aesmc_parameter_error_recorder_0.02_1_500_1.npy'))[0]
mean2=np.load(os.path.join(path2, 'aesmc_parameter_error_recorder_0.02_1_500_1.npy'))[0]
std2=np.load(os.path.join(path1, 'aesmc_parameter_error_recorder_0.02_1_500_1.npy'))[0]
mean3=np.load(os.path.join(path3, 'aesmc_parameter_error_recorder_0.02_1_500_1.npy'))[0]
std3=np.load(os.path.join(path1, 'aesmc_parameter_error_recorder_0.02_1_500_1.npy'))[0]
print(mean1)
# Out:
# 0.5290285

# %%
import numpy as np
import os

mean1=np.load(os.path.join(path1, 'aesmc_elbo_recorder_0.005_1_500_2.npy'))[0]
std1=np.load(os.path.join(path1, 'aesmc_elbo_recorder_0.005_1_500_2.npy'))[0][51:153]
# mean2=np.load(os.path.join(path2, 'aesmc_parameter_error_recorder_0.02_1_500_1.npy'))[0][51:71]
# std2=np.load(os.path.join(path1, 'aesmc_parameter_error_recorder_0.02_1_500_1.npy'))[0][51:71]
mean3=np.load(os.path.join(path3, 'aesmc_elbo_recorder_0.005_1_500_2.npy'))[0]
std3=np.load(os.path.join(path3, 'aesmc_elbo_recorder_0.005_1_500_2.npy'))[0][51:153]
print(mean1.shape, mean3.shape)
# Out:
# (153,) (153,)

# %%
# mean with confidence interval
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import sem, t

# Load data
# mean1 = np.load('mean1.npy')
# mean2 = np.load('mean2.npy')
# mean3 = np.load('mean3.npy')
# std1 = np.load('std1.npy')
# std2 = np.load('std2.npy')
# std3 = np.load('std3.npy')

# Confidence level
confidence = 0.95

# Lists to store means and standard deviations
means = [mean1, mean2, mean3]
stds = [std1, std2, std3]

labels = ["Online learning", "Pre-train", 'Supervised learning']
colors = ['blue','red', 'green']
colors_shade = ['blue','red', 'green']

# Plotting
plt.figure(figsize=(10, 8))
for i, (mean, std) in enumerate(zip(means, stds)):
    # n = mean.shape[0]
    # m = np.mean(mean)
    # std_err = sem(mean)
    # conf_interval = std_err * t.ppf((1 + confidence) / 2, n - 1) 
    plt.plot(np.arange(0, 9000), mean, label=labels[i], color=colors[i])
    # plt.plot(np.arange(1, 101), mean, label=labels[i])
    # plt.fill_between(np.arange(0, 50), mean - std, mean + std, color=colors_shade[i], alpha=0.3)

plt.legend(loc='center right', fontsize=28, ncol=1)
plt.tick_params(direction='in', labelsize=28)
plt.grid(alpha=0.2)
# plt.ylabel('RMSE', fontsize=28)
plt.ylabel('ELBO', fontsize=28)
plt.ylim([-50,20])
plt.xlabel('Time steps', fontsize=28)
# plt.xticks([0, 50, 101, 152], [0, 5000, 10000, 15000],fontsize=28)
plt.yticks(fontsize=28)
# plt.xticks(list(range(0, 51, 10)))
# plt.yticks(range(0, 30, 5))
# plt.title('RMSE error on validation set', fontsize=20)
plt.savefig(savepath, bbox_inches='tight', pad_inches=0.05)
plt.show()

# %%
path1 = "DPF-Merge/logs/de_mul_elbo_5_NF^False_DPF_0.25_0.001_resample^soft_cos_maze_nav01_0.001_1e-05_elbo_0.01_mix_split_0.9/data"
path2 = "DPF-Merge/logs/de_sys_elbo_5_NF^False_DPF_0.25_0.001_resample^soft_cos_maze_nav01_0.001_1e-05_elbo_0.01_mix_split_0.9/data"
savepath = "result/DPF-Merge-disk-nf.png"

# %%
import numpy as np
import os

mean1=np.load(os.path.join(path1, 'eval_loss_mean_epoch.npy'))
std1=np.load(os.path.join(path1, 'eval_loss_std_epoch.npy'))
mean2=np.load(os.path.join(path2, 'eval_loss_mean_epoch.npy'))
std2=np.load(os.path.join(path2, 'eval_loss_std_epoch.npy'))
print(mean1.shape)
# Out:
# (100,)

# %%
# mean with confidence interval
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import sem, t

# Load data
# mean1 = np.load('mean1.npy')
# mean2 = np.load('mean2.npy')
# mean3 = np.load('mean3.npy')
# std1 = np.load('std1.npy')
# std2 = np.load('std2.npy')
# std3 = np.load('std3.npy')

# Confidence level
confidence = 0.95

# Lists to store means and standard deviations
means = [mean1, mean2]
stds = [std1, std2]

labels = ["mul", "sys"]
colors = ['blue', 'red']

# Plotting
plt.figure(figsize=(10, 8))
for i, (mean, std) in enumerate(zip(means, stds)):
    n = mean.shape[0]
    m = np.mean(mean)
    std_err = sem(mean)
    conf_interval = std_err * t.ppf((1 + confidence) / 2, n - 1)
    plt.plot(np.arange(1, 101), mean, label=labels[i], color=colors[i])
    plt.fill_between(np.arange(1, 101), mean - conf_interval, mean + conf_interval, alpha=0.15)

plt.legend(loc='upper right', fontsize=28, ncol=1)
plt.tick_params(direction='in', labelsize=28)
plt.grid(alpha=0.2)
plt.ylabel('RMSE', fontsize=28)
plt.xlabel('Epoch', fontsize=28)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)
# plt.xticks(list(range(0, 51, 10)))
# plt.yticks(range(0, 30, 5))
# plt.title('RMSE error on validation set', fontsize=20)
plt.savefig(savepath, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
path1 = "../Normalizing-Flows-DPFs-main/Normalizing-Flows-DPFs-main/logs/2_NF^False_DPF_20.0_20.0_2.5_0.0001_resample^ot_cos/data"
path2 = "../Normalizing-Flows-DPFs-main/Normalizing-Flows-DPFs-main/logs/2_NF^True_DPF_20.0_20.0_2.5_0.0001_resample^ot_cos/data"
path3 = "../Normalizing-Flows-DPFs-main/Normalizing-Flows-DPFs-main/logs/2_NF^True_DPF_20.0_20.0_2.5_0.0001_resample^ot_CRNVP/data"
savepath = "result/DPF-Merge-disk-nf.png"

# %%
import numpy as np
import os

mean1=np.load(os.path.join(path1, 'eval_loss_epoch.npy'))
mean2=np.load(os.path.join(path2, 'eval_loss_epoch.npy'))
mean3=np.load(os.path.join(path3, 'eval_loss_epoch.npy'))
print(mean3.shape)
# Out:
# (700,)

# %%
# mean with confidence interval
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import sem, t


# Lists to store means and standard deviations
means = [mean1, mean2, mean3]

labels = ["False-False", "NF-False","NF-CRNVP"]
colors = ['blue', 'red', 'green']

# Plotting
plt.figure(figsize=(10, 8))
for i, (mean) in enumerate(means):
    plt.plot(mean, label=labels[i], color=colors[i])

plt.legend(loc='upper right', fontsize=28, ncol=1)
plt.tick_params(direction='in', labelsize=28)
plt.grid(alpha=0.2)
plt.ylabel('RMSE', fontsize=28)
plt.xlabel('Epoch', fontsize=28)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)
plt.savefig(savepath, bbox_inches='tight', pad_inches=0.1)
plt.show()
